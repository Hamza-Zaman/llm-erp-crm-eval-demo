# %% [markdown]
# # ERP/CRM Language Component Evaluation Walkthrough
# Quick walkthrough to run the three evaluations locally.

# %%
import pandas as pd
pd.read_csv('../data/contracts.csv').head()

# %%
# !python ../src/eval_contracts.py
# !python ../src/eval_leads.py
# !python ../src/eval_notes.py
